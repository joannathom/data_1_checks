# %% [markdown]
# <a href="https://colab.research.google.com/github/joannathom/data_1_checks/blob/main/Knowledgecheck1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -Pull in data from an API from https://apipheny.io/free-api/
# -Find two descriptive statistics about the data
# -Write a query in Pandas
# -Select and print the SECOND and THIRD columns in the data
# -Select and printthe FIRST 4 rowsof your data frame

# %%
#import statements
import pandas as pd
import requests as re
import json

# %%
#my api choice is the api
#pull in data from api
api_endpoint = "http://api.citybik.es/v2/networks"

response = re.get(api_endpoint)
response_json = response.json()
#
#df = pd.json_normalize(response_json['networks'])
df.head()
# Out:
#                                      company  \
# 0                           [ЗАО «СитиБайк»]
# 1             [Urban Infrastructure Partner]
# 2                        [Comunicare S.r.l.]
# 3                       [Cyclopolis Systems]
# 4  [Groundwork, Slough Borough Council, ITS]
#
#                                href                   id        name  \
# 0      /v2/networks/velobike-moscow      velobike-moscow    Velobike
# 1      /v2/networks/baerum-bysykkel      baerum-bysykkel    Bysykkel
# 2     /v2/networks/bicincitta-siena     bicincitta-siena  Bicincittà
# 3  /v2/networks/cyclopolis-maroussi  cyclopolis-maroussi  Cyclopolis
# 4    /v2/networks/cycle-hire-slough    cycle-hire-slough  Cycle Hire
#
#   location.city location.country  location.latitude  location.longitude  \
# 0        Moscow               RU          55.750000           37.616667
# 1         Bærum               NO          59.894550           10.546343
# ...

# %%
#Find and print Two descriptive details about your data
df['location.latitude'].mean()
# Out:
# 42.70458156688647

# %%
df['location.country'].describe()
# Out:
# count     612
# unique     52
# top        IT
# freq      123
# Name: location.country, dtype: object

# %%
df['location.city'].value_counts()
# Out:
# Berlin           2
# Rouen            2
# Bratislava       2
# São Paulo        2
# Nicosia          2
#                 ..
# Abu Dhabi        1
# Castellucchio    1
# Nice             1
# Noto             1
# Sion             1
# Name: location.city, Length: 602, dtype: int64

# %%
#Write a query in Pandas to select a particular set of data.
mask = df['location.city'] == 'Moscow'
Mossi = df[mask]
Mossi
# Out:
#             company                          href               id      name  \
# 0  [ЗАО «СитиБайк»]  /v2/networks/velobike-moscow  velobike-moscow  Velobike
#
#   location.city location.country  location.latitude  location.longitude  \
# 0        Moscow               RU              55.75           37.616667
#
#   source gbfs_href license.name license.url ebikes
# 0    NaN       NaN          NaN         NaN    NaN

# %%
#Select and print the SECOND and THIRD of the Data Query.
df [['href' , 'id']]
# Out:
#                                        href                         id
# 0              /v2/networks/velobike-moscow            velobike-moscow
# 1              /v2/networks/baerum-bysykkel            baerum-bysykkel
# 2             /v2/networks/bicincitta-siena           bicincitta-siena
# 3          /v2/networks/cyclopolis-maroussi        cyclopolis-maroussi
# 4            /v2/networks/cycle-hire-slough          cycle-hire-slough
# ..                                      ...                        ...
# 607   /v2/networks/publibike-sottoceneri-ti   publibike-sottoceneri-ti
# 608         /v2/networks/publibike-fribourg         publibike-fribourg
# 609  /v2/networks/publibike-lausanne-morges  publibike-lausanne-morges
# 610             /v2/networks/publibike-sion             publibike-sion
# 611         /v2/networks/lovelolibreservice         lovelolibreservice
#
# [612 rows x 2 columns]

# %%
df.head(4)
# Out:
#                           company                              href  \
# 0                [ЗАО «СитиБайк»]      /v2/networks/velobike-moscow
# 1  [Urban Infrastructure Partner]      /v2/networks/baerum-bysykkel
# 2             [Comunicare S.r.l.]     /v2/networks/bicincitta-siena
# 3            [Cyclopolis Systems]  /v2/networks/cyclopolis-maroussi
#
#                     id        name location.city location.country  \
# 0      velobike-moscow    Velobike        Moscow               RU
# 1      baerum-bysykkel    Bysykkel         Bærum               NO
# 2     bicincitta-siena  Bicincittà         Siena               IT
# 3  cyclopolis-maroussi  Cyclopolis      Maroussi               GR
#
#    location.latitude  location.longitude  \
# 0          55.750000           37.616667
# 1          59.894550           10.546343
# 2          43.318600           11.330600
# 3          38.056872           23.808330
#
# ...
